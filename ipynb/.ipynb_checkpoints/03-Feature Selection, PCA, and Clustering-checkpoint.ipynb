# %%
cd ..
# Out:
# /home/jovyan/Ames_Housing_Project

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as st

from IPython.display import display
# %matplotlib inline

# %%
one_hot_housing_df = pd.read_pickle('final_one_hot_sc.p')

# %%
one_hot_housing_df.head()
# Out:
#     LotFrontage   LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# Id
# 1     -0.043080 -0.065830   0.525494      0.441038    0.598461    0.390174
# 2      0.282123  0.057485   0.084614     -0.209405   -0.405349    0.444600
# 3      0.027507  0.210770   0.493040      0.417104    0.562464    0.327844
# 4     -0.168179  0.052438  -0.934033     -0.355154   -0.405349    0.192679
# 5      0.358665  0.439912   0.476802      0.369201    0.708201    0.377655
#
#     BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  FirstFlrSF          ...            \
# Id                                                          ...
# 1     -0.17823  -0.168977     0.001975   -0.401354          ...
# 2     -0.17823   0.001909     0.170817    0.210649          ...
# 3     -0.17823   0.115667     0.033331   -0.287695          ...
# 4     -0.17823   0.174333    -0.052045   -0.218961          ...
# 5     -0.17823   0.148245     0.128493    0.057237          ...
#
#     SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# Id
# 1                0             0             0            1
# 2                0             0             0            1
# 3                0             0             0            1
# 4                0             0             0            1
# 5                0             0             0            1
#
#     SaleCondition_Abnorml  SaleCondition_AdjLand  SaleCondition_Alloca  \
# Id
# 1                       0                      0                     0
# 2                       0                      0                     0
# 3                       0                      0                     0
# 4                       1                      0                     0
# 5                       0                      0                     0
#
#     SaleCondition_Family  SaleCondition_Normal  SaleCondition_Partial
# Id
# 1                      0                     1                      0
# 2                      0                     1                      0
# 3                      0                     1                      0
# 4                      0                     0                      0
# 5                      0                     1                      0
#
# [5 rows x 383 columns]

# %%
one_hot_housing_df.shape
# Out:
# (1437, 383)

# %%
housing_target = one_hot_housing_df.SalePrice

# %%
train_df = one_hot_housing_df
train_df.drop("SalePrice", axis=1, inplace=True)

# %%
train_df.shape
# Out:
# (1437, 382)

# %%
#Attempted to run sample to get most important features on different validation sets,
#but was unable to get the code to work, so due to time just did one

# %%
def sample_training_set(X_train, y_train, n_pcnt):
    n = X_train.shape[0]*n_pcnt//100
    return n, X_train[:n], y_train[:n]

def time_function_call(function_call):
    start = time()
    result = function_call
    execution_time = time() - start
    return result, execution_time

def run_model(model, model_name, n_pcnt, data, labels):

    X_train, X_test, y_train, y_test = train_test_split(data, labels, stratify=labels)

    
    n, X_samp, y_samp = sample_training_set(X_train, y_train, n_pcnt)
    
    _, fit_time = time_function_call(
        model.fit(X_samp, y_samp))
    
    train_pred, train_pred_time = time_function_call(
        model.predict(X_samp))
    
    test_pred, test_pred_time = time_function_call(
        model.predict(X_test))    
    
    return {
            'model' : model,
            'model_name' : model_name,
            'n_pcnt' : n_pcnt,
            'n' : n,
            'f1_train_score' : f1_score(y_samp, train_pred),
            'f1_test_score' : f1_score(y_test, test_pred),
            'accuracy_train_score' : model.score(X_samp, y_samp),
            'accuracy_test_score' : model.score(X_test, y_test),
            'fit_time' : fit_time,
            'train_pred_time' : train_pred_time,
            'test_pred_time' : test_pred_time}

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from tqdm import tqdm 
from time import time

# %%
test_scores = []
for feature in train_df.columns:
    results = run_model(LogisticRegression(), 'variable ranking', 50, train_df[[feature]], housing_target)
    test_score = results['f1_test_score']
    if test_score > 0:
        test_scores.append({'feature': feature, 'score' : test_score})

# %%
# %run src/load_data.py

# %%
from sklearn.tree import DecisionTreeRegressor
# load data
data_array_X = one_hot_housing_df.values
data_array_Y = housing_target
X = data_array_X
Y = data_array_Y


model = DecisionTreeRegressor(max_features=200)
model.fit(X, Y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=200,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
feature_importances = model.feature_importances_
features = one_hot_housing_df.columns
feature_importances = pd.Series(feature_importances.T.ravel(), index=features)

# %%
sorted_importances = feature_importances.sort_values(ascending=False)
sorted_importances = pd.DataFrame(sorted_importances, columns=['importances'])
sorted_importances['importance_feature'] = sorted_importances.index
sorted_importances.reset_index(drop=True, inplace=True)
sorted_importances.head(10)
# Out:
#    importances importance_feature
# 0     0.356889          YearBuilt
# 1     0.164359       GarageCars_3
# 2     0.110293          GrLivArea
# 3     0.068215         FirstFlrSF
# 4     0.065037       Fireplaces_0
# 5     0.027904        TotalBsmtSF
# 6     0.018622        SecondFlrSF
# 7     0.016695         BsmtFinSF1
# 8     0.016571            LotArea
# 9     0.010606    TotRmsAbvGrd_11

# %%
from sklearn.decomposition import PCA

# %%
final_ten = one_hot_housing_df[['ExterQual_TA','GarageCars_3','GrLivArea',
                                'TotalBsmtSF','BsmtFinSF1','SecondFlrSF','GarageCars_2',
                                'BedroomAbvGr_3','LotArea','YearBuilt']]
pca = PCA()
pca.fit(final_ten)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
plt.plot( range(0, 10), pca.explained_variance_ratio_)

# %%
import lib.viz_helper as viz
pca_df = viz.pca_results(final_ten, pca)

# %%
import lib.visuals as vs

# %%
whos DataFrame
# Out:
# Variable             Type         Data/Info
# -------------------------------------------
# final_ten            DataFrame          ExterQual_TA  Garag<...>n[1437 rows x 10 columns]
# one_hot_housing_df   DataFrame          LotFrontage   LotAr<...>[1437 rows x 382 columns]
# pca_df               DataFrame                  Explained V<...>143   0.0012    -0.2010
# sorted_importances   DataFrame         importances    impor<...>n\n[382 rows x 2 columns]
# train_df             DataFrame          LotFrontage   LotAr<...>[1437 rows x 382 columns]

# %%
whos PCA
# Out:
# Variable   Type    Data/Info
# ----------------------------
# pca        PCA     PCA(copy=True, iterated_p<...>', tol=0.0, whiten=False)

# %%
pca_df.head()
# Out:
#              Explained Variance  ExterQual_TA  GarageCars_3  GrLivArea  \
# Dimension 1              0.2376        0.4831       -0.1953    -0.4877
# Dimension 2              0.1678        0.0092        0.0354     0.3734
# Dimension 3              0.1306        0.3184        0.1223     0.1885
# Dimension 4              0.1198       -0.2999        0.3870    -0.0436
# Dimension 5              0.1029       -0.0819        0.1116    -0.1898
#
#              TotalBsmtSF  BsmtFinSF1  SecondFlrSF  GarageCars_2  \
# Dimension 1      -0.3026     -0.1051      -0.2033       -0.2115
# Dimension 2      -0.3263     -0.5197       0.6255       -0.0955
# Dimension 3       0.3306      0.2467       0.0603       -0.3964
# Dimension 4       0.1697     -0.0942      -0.1088       -0.7219
# Dimension 5      -0.1721     -0.4122      -0.1399       -0.2214
#
#              BedroomAbvGr_3  LotArea  YearBuilt
# Dimension 1         -0.1436  -0.2367    -0.4746
# Dimension 2         -0.1058   0.0148    -0.2664
# Dimension 3          0.2669   0.5444    -0.3869
# Dimension 4         -0.3529  -0.2364     0.0859
# Dimension 5          0.7993  -0.0202     0.1934

# %%
final_ten_pca = pd.DataFrame(pca.transform(final_ten))
dims_labels = ['Dimension 1', 'Dimension 2', 'Dimension 3', 'Dimension 4', 
               'Dimension 5', 'Dimension 6', 'Dimension 7', 'Dimension 8', 
               'Dimension 9', 'Dimension 10']
final_ten_pca.columns = dims_labels

# %%
final_pca_clusters = vs.Clusters(final_ten_pca, [2,3,4])
final_pca_clusters.cluster_plots()
# Out:
#  67%|██████▋   | 2/3 [00:00<00:00,  8.16it/s]
# For n_clusters = 2 the silhouette score is 0.1894205700330205.
# For n_clusters = 3 the silhouette score is 0.19744190712260715.
# 100%|██████████| 3/3 [00:00<00:00,  8.47it/s]
# For n_clusters = 4 the silhouette score is 0.2118419546908024.

# %%
final_pca_clusters = vs.Clusters(final_ten_pca, [3,6,9])
final_pca_clusters.cluster_plots()
# Out:
#  67%|██████▋   | 2/3 [00:00<00:00,  9.76it/s]
# For n_clusters = 3 the silhouette score is 0.19744190712260715.
# For n_clusters = 6 the silhouette score is 0.23224483566140514.
# 100%|██████████| 3/3 [00:00<00:00,  8.73it/s]
# For n_clusters = 9 the silhouette score is 0.25160267739642883.

# %%
final_pca_clusters = vs.Clusters(final_ten_pca, [8,16,24])
final_pca_clusters.cluster_plots()
# Out:
#  67%|██████▋   | 2/3 [00:00<00:00,  6.84it/s]
# For n_clusters = 8 the silhouette score is 0.24065698116432083.
# For n_clusters = 16 the silhouette score is 0.30167257197344627.
# 100%|██████████| 3/3 [00:00<00:00,  5.70it/s]
# For n_clusters = 24 the silhouette score is 0.32718155694800194.
